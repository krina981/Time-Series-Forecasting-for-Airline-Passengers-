# %% [markdown]
# # Time Series Analysis and Forecasting with Python
#
# This notebook demonstrates various time series analysis and forecasting techniques using Python libraries such as pandas, numpy, matplotlib, statsmodels, and tensorflow.
#
# ## Importing Required Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.api import ExponentialSmoothing
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tools.eval_measures import aic, bic
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.preprocessing import MinMaxScaler
import warnings


warnings.filterwarnings("ignore")

# %% [markdown]
# # Load the dataset

# %%
data = pd.read_csv("AirPassengers.csv")

# %%
print(data.head())
# Out:
#      Timeline     Month  Year  Number_of_Passengers  Unnamed: 4
# 0  01-01-1949   January  1949                 112.0         NaN
# 1  01-02-1949  February  1949                 118.0         NaN
# 2  01-03-1949     March  1949                 132.0         NaN
# 3  01-04-1949     April  1949                 129.0         NaN
# 4  01-05-1949       May  1949                 121.0         NaN

# %% [markdown]
# # EDA

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Timeline              144 non-null    object
#  1   Month                 144 non-null    object
#  2   Year                  144 non-null    int64
#  3   Number_of_Passengers  144 non-null    float64
#  4   Unnamed: 4            0 non-null      float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 5.8+ KB
# None

# %%
data['Timeline'] = pd.to_datetime(data['Timeline'], format='%d-%m-%Y')

# %%
data.set_index('Timeline', inplace=True)

# %%
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Number_of_Passengers'])  # Plotting date vs passenger counts
plt.title('Passenger Counts Over Time')
plt.xlabel('Timeline')
plt.ylabel('Number of Passengers')
plt.show()

# %% [markdown]
# # Check for stationarity

# %%
def test_stationarity(timeseries):
    # Dickey-Fuller test
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    for key, value in dftest[4].items():
        dfoutput['Critical Value (%s)' % key] = value
    print(dfoutput)

test_stationarity(data['Number_of_Passengers'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   0.815369
# p-value                          0.991880
# #Lags Used                      13.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64

# %% [markdown]
# # Decompose the time series

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(data['Number_of_Passengers'], model='additive', period=12)
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# %%
plt.figure(figsize=(12, 8))
# Plot original data
plt.subplot(411)
plt.plot(data.index, data['Number_of_Passengers'], label='Original', color='black')
plt.legend(loc='best')

# Plot trend
plt.subplot(412)
plt.plot(data.index, trend, label='Trend', color='blue')
plt.legend(loc='best')

# Plot seasonal component
plt.subplot(413)
plt.plot(data.index, seasonal, label='Seasonality', color='red')
plt.legend(loc='best')

# Plot residuals
plt.subplot(414)
plt.plot(data.index, residual, label='Residuals', color='green')
plt.legend(loc='best')

plt.tight_layout()
plt.show()

# %% [markdown]
# # ACF and PACF plots

# %%
plot_acf(data['Number_of_Passengers'], lags=50)
plt.show()

plot_pacf(data['Number_of_Passengers'], lags=50)
plt.show()

# %% [markdown]
# # Fit ARIMA model

# %%
from statsmodels.tools.eval_measures import aic, bic
arima_model = ARIMA(data['Number_of_Passengers'], order=(5, 1, 0))
arima_results = arima_model.fit()

# %%
# Calculate AIC and BIC
aic_value = aic(arima_results.llf, arima_results.nobs, arima_results.df_model)
bic_value = bic(arima_results.llf, arima_results.nobs, arima_results.df_model)

# Print AIC and BIC
print('AIC:', aic_value)
print('BIC:', bic_value)
# Out:
# AIC: 1390.134632147816
# BIC: 1407.953511945272

# %%
# Forecast
forecast = arima_results.forecast(steps=12)

# %%
# Plot original data and ARIMA forecast
plt.figure(figsize=(12, 6))
plt.plot(data.index, data['Number_of_Passengers'], label='Original', color='blue')
plt.plot(pd.date_range(start=data.index[-1], periods=13, freq='M')[1:], forecast, color='red', label='Forecast')
plt.title('ARIMA Forecast')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.legend()
plt.show()

# %% [markdown]
# # LSTM model

# %%
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(np.array(data['Number_of_Passengers']).reshape(-1,1))

train_size = int(len(data_scaled) * 0.7)
test_size = len(data_scaled) - train_size
train, test = data_scaled[0:train_size,:], data_scaled[train_size:len(data_scaled),:]

def create_dataset(dataset, time_step=1):
    X, Y = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        X.append(a)
        Y.append(dataset[i + time_step, 0])
    return np.array(X), np.array(Y)

# %%
time_step = 10
X_train, Y_train = create_dataset(train, time_step)
X_test, Y_test = create_dataset(test, time_step)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
model_lstm = Sequential()
model_lstm.add(LSTM(50, return_sequences=True, input_shape=(time_step, 1)))
model_lstm.add(LSTM(50, return_sequences=True))
model_lstm.add(LSTM(50))
model_lstm.add(Dense(1))
model_lstm.compile(loss='mean_squared_error', optimizer='adam')
model_lstm.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 8s 2s/step - loss: 0.0676 - val_loss: 0.3133
# Epoch 2/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0467 - val_loss: 0.2217
# Epoch 3/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0273 - val_loss: 0.1291
# Epoch 4/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0120 - val_loss: 0.0514
# Epoch 5/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0110 - val_loss: 0.0270
# Epoch 6/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0178 - val_loss: 0.0294
# Epoch 7/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0143 - val_loss: 0.0450
# Epoch 8/100
# 2/2 [==============================] - 0s 60ms/step - loss: 0.0093 - val_loss: 0.0683
# Epoch 9/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0086 - val_loss: 0.0870
# Epoch 10/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0097 - val_loss: 0.0940
# Epoch 11/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0104 - val_loss: 0.0892
# Epoch 12/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0099 - val_loss: 0.0759
# Epoch 13/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0089 - val_loss: 0.0584
# Epoch 14/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0075 - val_loss: 0.0443
# Epoch 15/100
# 2/2 [==============================] - 0s 203ms/step - loss: 0.0071 - val_loss: 0.0355
# Epoch 16/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0072 - val_loss: 0.0327
# Epoch 17/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0069 - val_loss: 0.0336
# Epoch 18/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0064 - val_loss: 0.0363
# Epoch 19/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0062 - val_loss: 0.0387
# Epoch 20/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0063 - val_loss: 0.0372
# Epoch 21/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0062 - val_loss: 0.0330
# Epoch 22/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0059 - val_loss: 0.0298
# Epoch 23/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0058 - val_loss: 0.0283
# Epoch 24/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0060 - val_loss: 0.0282
# Epoch 25/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0060 - val_loss: 0.0284
# Epoch 26/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0059 - val_loss: 0.0294
# Epoch 27/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0058 - val_loss: 0.0301
# Epoch 28/100
# 2/2 [==============================] - 0s 94ms/step - loss: 0.0060 - val_loss: 0.0299
# Epoch 29/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0059 - val_loss: 0.0285
# Epoch 30/100
# 2/2 [==============================] - 0s 141ms/step - loss: 0.0058 - val_loss: 0.0280
# Epoch 31/100
# 2/2 [==============================] - 0s 156ms/step - loss: 0.0059 - val_loss: 0.0280
# Epoch 32/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0059 - val_loss: 0.0284
# Epoch 33/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0057 - val_loss: 0.0305
# Epoch 34/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0058 - val_loss: 0.0329
# Epoch 35/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0060 - val_loss: 0.0328
# Epoch 36/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0058 - val_loss: 0.0302
# Epoch 37/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0058 - val_loss: 0.0282
# Epoch 38/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0059 - val_loss: 0.0280
# Epoch 39/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0059 - val_loss: 0.0292
# Epoch 40/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0058 - val_loss: 0.0312
# Epoch 41/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0057 - val_loss: 0.0322
# Epoch 42/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0058 - val_loss: 0.0321
# Epoch 43/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0057 - val_loss: 0.0305
# Epoch 44/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0057 - val_loss: 0.0293
# Epoch 45/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0057 - val_loss: 0.0289
# Epoch 46/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0057 - val_loss: 0.0291
# Epoch 47/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0057 - val_loss: 0.0303
# Epoch 48/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0057 - val_loss: 0.0329
# Epoch 49/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0058 - val_loss: 0.0337
# Epoch 50/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0058 - val_loss: 0.0319
# Epoch 51/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0057 - val_loss: 0.0290
# Epoch 52/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0057 - val_loss: 0.0279
# Epoch 53/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0059 - val_loss: 0.0283
# Epoch 54/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0057 - val_loss: 0.0307
# Epoch 55/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0057 - val_loss: 0.0327
# Epoch 56/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0057 - val_loss: 0.0320
# Epoch 57/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0304
# Epoch 58/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0056 - val_loss: 0.0291
# Epoch 59/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0057 - val_loss: 0.0293
# Epoch 60/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0056 - val_loss: 0.0303
# Epoch 61/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0321
# Epoch 62/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0057 - val_loss: 0.0343
# Epoch 63/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0057 - val_loss: 0.0338
# Epoch 64/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0057 - val_loss: 0.0322
# Epoch 65/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0309
# Epoch 66/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0305
# Epoch 67/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0301
# Epoch 68/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0303
# Epoch 69/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0057 - val_loss: 0.0311
# Epoch 70/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0056 - val_loss: 0.0305
# Epoch 71/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0300
# Epoch 72/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0056 - val_loss: 0.0295
# Epoch 73/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0297
# Epoch 74/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0056 - val_loss: 0.0301
# Epoch 75/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0316
# Epoch 76/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0056 - val_loss: 0.0339
# Epoch 77/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0057 - val_loss: 0.0341
# Epoch 78/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0057 - val_loss: 0.0334
# Epoch 79/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0301
# Epoch 80/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0282
# Epoch 81/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0058 - val_loss: 0.0290
# Epoch 82/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0322
# Epoch 83/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0057 - val_loss: 0.0367
# Epoch 84/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0057 - val_loss: 0.0364
# Epoch 85/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0334
# Epoch 86/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0055 - val_loss: 0.0303
# Epoch 87/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0057 - val_loss: 0.0290
# Epoch 88/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0058 - val_loss: 0.0303
# Epoch 89/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0331
# Epoch 90/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0055 - val_loss: 0.0351
# Epoch 91/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0056 - val_loss: 0.0352
# Epoch 92/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0056 - val_loss: 0.0333
# Epoch 93/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0055 - val_loss: 0.0321
# Epoch 94/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0055 - val_loss: 0.0314
# Epoch 95/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0055 - val_loss: 0.0332
# Epoch 96/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0055 - val_loss: 0.0364
# Epoch 97/100
# 2/2 [==============================] - 0s 62ms/step - loss: 0.0055 - val_loss: 0.0373
# Epoch 98/100
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0055 - val_loss: 0.0355
# Epoch 99/100
# 2/2 [==============================] - 0s 47ms/step - loss: 0.0055 - val_loss: 0.0330
# Epoch 100/100
# 2/2 [==============================] - 0s 63ms/step - loss: 0.0055 - val_loss: 0.0323

# %% [markdown]
# # Prediction

# %%
train_predict = model_lstm.predict(X_train)
test_predict = model_lstm.predict(X_test)
# Out:
# 3/3 [==============================] - 1s 8ms/step
# 2/2 [==============================] - 0s 0s/step

# %%
# Inverse transform predictions
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# %%
# Check the lengths of data['Number_of_Passengers'] and test_predict
print("Length of Number_of_Passengers:", len(data['Number_of_Passengers']))
print("Length of test_predict:", len(test_predict))
# Out:
# Length of Number_of_Passengers: 144
# Length of test_predict: 33

# %% [markdown]
# # AIC and BIC for LSTM

# %%
AIC_lstm = aic(data['Number_of_Passengers'].tail(len(test_predict)), test_predict[:, 0], 2)
BIC_lstm = bic(data['Number_of_Passengers'].tail(len(test_predict)), test_predict[:, 0], 2)
print("AIC LSTM:", AIC_lstm)
print("BIC LSTM:", BIC_lstm)

# Plot LSTM predictions
plt.figure(figsize=(10, 6))
plt.plot(data.index[-len(test_predict):], test_predict[:, 0], label='LSTM Test Predictions')
plt.plot(data.index[-len(test_predict):], data['Number_of_Passengers'].tail(len(test_predict)), label='Original Data')
plt.title('LSTM Model Predictions')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.legend()
plt.show()
# Out:
# AIC LSTM: Timeline
# 1958-04-01    -692.0
# 1958-05-01    -722.0
# 1958-06-01    -866.0
# 1958-07-01    -978.0
# 1958-08-01   -1006.0
# 1958-09-01    -804.0
# 1958-10-01    -714.0
# 1958-11-01    -616.0
# 1958-12-01    -670.0
# 1959-01-01    -716.0
# 1959-02-01    -680.0
# 1959-03-01    -808.0
# 1959-04-01    -788.0
# 1959-05-01    -836.0
# 1959-06-01    -940.0
# 1959-07-01   -1092.0
# 1959-08-01   -1114.0
# 1959-09-01    -922.0
# 1959-10-01    -810.0
# 1959-11-01    -720.0
# 1959-12-01    -806.0
# 1960-01-01    -830.0
# 1960-02-01    -778.0
# 1960-03-01    -834.0
# 1960-04-01    -918.0
# 1960-05-01    -940.0
# 1960-06-01   -1066.0
# 1960-07-01   -1240.0
# 1960-08-01   -1208.0
# 1960-09-01   -1012.0
# 1960-10-01    -918.0
# 1960-11-01    -776.0
# 1960-12-01    -860.0
# Name: Number_of_Passengers, dtype: float64
# BIC LSTM: Timeline
# 1958-04-01    -684.114569
# 1958-05-01    -714.113007
# 1958-06-01    -858.149305
# 1958-07-01    -970.213553
# 1958-08-01    -998.280720
# 1958-09-01    -796.300691
# 1958-10-01    -706.269597
# 1958-11-01    -608.206100
# 1958-12-01    -662.163604
# 1959-01-01    -708.130266
# 1959-02-01    -672.091437
# 1959-03-01    -800.080629
# 1959-04-01    -780.066831
# 1959-05-01    -828.060403
# 1959-06-01    -932.089130
# 1959-07-01   -1084.147207
# 1959-08-01   -1106.213497
# 1959-09-01    -914.210504
# 1959-10-01    -802.166011
# 1959-11-01    -712.088053
# 1959-12-01    -798.027918
# 1960-01-01    -821.986105
# 1960-02-01    -769.941126
# 1960-03-01    -825.927930
# 1960-04-01    -909.913812
# 1960-05-01    -931.911195
# 1960-06-01   -1057.928885
# 1960-07-01   -1231.978472
# 1960-08-01   -1200.032830
# 1960-09-01   -1004.032326
# 1960-10-01    -909.992886
# 1960-11-01    -767.928708
# 1960-12-01    -851.885995
# Name: Number_of_Passengers, dtype: float64

# %% [markdown]
# # Exponential smoothing model

# %%
model_exp = ExponentialSmoothing(data['Number_of_Passengers'], trend='additive', seasonal='additive', seasonal_periods=12)
results_exp = model_exp.fit()

# %%
# Print summary, AIC, and BIC
print(results_exp.summary())
print('AIC:', results_exp.aic)
print('BIC:', results_exp.bic)
# Out:
#                        ExponentialSmoothing Model Results
# ================================================================================
# Dep. Variable:     Number_of_Passengers   No. Observations:                  144
# Model:             ExponentialSmoothing   SSE                          21564.431
# Optimized:                         True   AIC                            753.294
# Trend:                         Additive   BIC                            800.811
# Seasonal:                      Additive   AICC                           758.766
# Seasonal Periods:                    12   Date:                 Sun, 05 May 2024
# Box-Cox:                          False   Time:                         18:25:30
# Box-Cox Coeff.:                    None
# =================================================================================
#                           coeff                 code              optimized
# ---------------------------------------------------------------------------------
# smoothing_level               0.2525499                alpha                 True
# smoothing_trend              9.7655e-07                 beta                 True
# smoothing_seasonal            0.7474446                gamma                 True
# initial_level                 118.43093                  l.0                 True
# initial_trend                 2.5946936                  b.0                 True
# initial_seasons.0            -9.0656226                  s.0                 True
# initial_seasons.1            -3.4370801                  s.1                 True
# initial_seasons.2             9.0056525                  s.2                 True
# initial_seasons.3             3.8174226                  s.3                 True
# initial_seasons.4            -4.9328355                  s.4                 True
# initial_seasons.5             9.1762030                  s.5                 True
# initial_seasons.6             21.383005                  s.6                 True
# initial_seasons.7             18.846107                  s.7                 True
# initial_seasons.8             4.6190084                  s.8                 True
# initial_seasons.9            -14.340425                  s.9                 True
# initial_seasons.10           -28.914435                 s.10                 True
# initial_seasons.11           -12.438151                 s.11                 True
# ---------------------------------------------------------------------------------
# AIC: 753.2941591103325
# BIC: 800.8111719035486

# %%
# Plot the original data and the exponential smoothing predictions
plt.figure(figsize=(10, 6))
plt.plot(data.index, data['Number_of_Passengers'], label='Original Data')
plt.plot(data.index, results_exp.fittedvalues, label='Exponential Smoothing Fitted Values')
plt.plot(data.index, results_exp.forecast(len(data)), label='Exponential Smoothing Forecast')
plt.title('Exponential Smoothing Model')
plt.xlabel('Year')
plt.ylabel('Number of Passengers')
plt.legend()
plt.show()
